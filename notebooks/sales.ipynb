# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
print("✅ All imports working!")
# Out:
# ✅ All imports working!

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("../data/amazon.csv")

# Show first few rows
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
#Getting to know the basic information about the dataset

print("Shape:", df.shape) #1465, 16 which means 1465 rows and 16 columns

# Column names
print("\nColumns:\n", df.columns.tolist()) #Dtype object means string data type 

# Data types and missing values
print("\nInfo:")
df.info()
# Out:
# Shape: (1465, 16)
#
# Columns:
#  ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
# ...

# %%
# Count missing values
print("\nMissing values per column:")
print(df.isnull().sum())

# Look at random samples
df.sample(5)

#Deleted
# Out:
# Missing values per column:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64
#       product_id                                       product_name  \
# 855   B07L9FW9GF  Zebronics Zeb-Power Wired USB Mouse, 3-Button,...
# 1330  B09PDZNSBG  Goodscity Garment Steamer for Clothes, Steam I...
# 284   B08RZ12GKR            Tata Sky Digital TV HD Setup Box Remote
# 655   B0B1F6GQPS  Boult Audio FXCharge with ENC, 32H Playtime, 5...
# 492   B0B53NXFFR  PTron Newly Launched Force X10 Bluetooth Calli...
#
#                                                category discounted_price  \
# ...

# %%
#Two ratings value were missing, Checking if deleting them would affect the dataset
# Display rows where rating_count is missing
missing_rating_count = df[df['rating_count'].isnull()]
missing_rating_count
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
#
#     actual_price discount_percentage rating rating_count  \
# 282         ₹999                 80%    3.0          NaN
# 324         ₹999                 75%    5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# 324  AGJC5O5H5BBXWUV7WRIEIOOR3TVQ  Abdul Gafur  RQXD5SAMMPC6L
#
# ...

# %%
#Since there are only 2 rows with missing rating_count, we can drop the

df = df.dropna(subset=['rating_count'])

# Confirm the change
print("Shape after dropping:", df.shape)
print("Missing values in rating_count after cleanup:", df['rating_count'].isnull().sum())
# Out:
# Shape after dropping: (1463, 16)
# Missing values in rating_count after cleanup: 0

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
#Right now, columns like discounted_price, actual_price, and discount_percentage are stored as strings with symbols (₹, %, ,).

#Let's clean these columns by removing the symbols and converting them to numeric values.
# Remove ₹, commas, and % then convert to numeric
df['discounted_price'] = df['discounted_price'].replace('[₹,]', '', regex=True).astype(float)
df['actual_price'] = df['actual_price'].replace('[₹,]', '', regex=True).astype(float)
df['discount_percentage'] = df['discount_percentage'].replace('%', '', regex=True).astype(float)

# Convert rating and rating_count to numeric too
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df['rating_count'] = df['rating_count'].replace(',', '', regex=True).astype(float)

# Check the result
print("\nFirst few rows after cleaning:")
df.head()
# Out:
# First few rows after cleaning:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1463 non-null   object
#  1   product_name         1463 non-null   object
#  2   category             1463 non-null   object
#  3   discounted_price     1463 non-null   float64
#  4   actual_price         1463 non-null   float64
#  5   discount_percentage  1463 non-null   float64
#  6   rating               1462 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1463 non-null   object
#  9   user_id              1463 non-null   object
#  10  user_name            1463 non-null   object
#  11  review_id            1463 non-null   object
#  12  review_title         1463 non-null   object
#  13  review_content       1463 non-null   object
#  14  img_link             1463 non-null   object
# ...

# %%
df.describe() # Gives statistical summary of numerical columns
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1463.000000    1463.000000          1463.000000  1462.000000
# mean        3129.277122    5451.068544            47.650718     4.096717
# std         6948.222850   10881.018448            21.622373     0.289497
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1690.000000            50.000000     4.100000
# 75%         1999.000000    4312.500000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
# make sense most products have very less discounts
plt.figure(figsize=(10, 6))
plt.hist(df['discounted_price'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Discounted Prices')
plt.xlabel('Discounted Price (₹)')
plt.ylabel('Number of Products')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# /opt/anaconda3/envs/amazon-recommender/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8377 (\N{INDIAN RUPEE SIGN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# make sense most products have very less value of price
plt.figure(figsize=(10, 6))
plt.hist(df['actual_price'], bins=30, color='salmon', edgecolor='black')
plt.title('Distribution of Actual Prices')
plt.xlabel('Actual Price (₹)')
plt.ylabel('Number of Products')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# so many outliers before feature engineering would be better to perform feature scaling
sns.boxplot(x='discounted_price', data=df, color='lightgreen')
# Out:
# <Axes: xlabel='discounted_price'>

# %%
# so many outliers before feature engineering would be better to perform feature scaling
sns.boxplot(x='actual_price', data=df, color='lightgreen')
# Out:
# <Axes: xlabel='actual_price'>

# %%
# discount percentage is spreaded nice and evenly
sns.boxplot(x='discount_percentage', data=df, color='lightgreen')
# Out:
# <Axes: xlabel='discount_percentage'>

# %%
# does higher discount_percentage lead to higher rating?
# rating does not seem to be affected by discount percentage
sns.scatterplot(x='discount_percentage', y='rating', data=df)
# Out:
# <Axes: xlabel='discount_percentage', ylabel='rating'>

# %%
# are popular products rated higher?
sns.scatterplot(x='rating_count', y='rating', data=df)
# Out:
# <Axes: xlabel='rating_count', ylabel='rating'>

# %%
# which catories have the highest average ratings?
df_grouped = df.groupby('category')['rating'].mean().sort_values(ascending=False).nlargest(10).reset_index()
plt.figure(figsize=(12, 6))
plt.bar(df_grouped['category'], df_grouped['rating'], color='orchid')
plt.xticks(rotation=45, ha='right')
plt.title('Average Rating by Category')
plt.xlabel('Category')
plt.ylabel('Average Rating')
plt.show()

# %%
# heatmap to see correlations
df_floated = df.select_dtypes(include=['float64'])
sns.heatmap(df_floated.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2       24269.0
# ...

# %%
df['category'].head()
# Out:
# 0    Computers&Accessories|Accessories&Peripherals|...
# 1    Computers&Accessories|Accessories&Peripherals|...
# 2    Computers&Accessories|Accessories&Peripherals|...
# 3    Computers&Accessories|Accessories&Peripherals|...
# 4    Computers&Accessories|Accessories&Peripherals|...
# Name: category, dtype: object

# %%
print("Unique categories:", df['category'].nunique())
# Out:
# Unique categories: 211

# %%
#Most common categories
category_counts = df['category'].value_counts().head(10)
print(category_counts)
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        231
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables                                            24
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
category_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Product Categories')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.show()

# %%
# Average text lengths
df['name_len'] = df['product_name'].str.split().str.len()
df['review_len'] = df['review_content'].str.split().str.len()
df[['name_len', 'review_len']].describe()
# Out:
#           name_len   review_len
# count  1463.000000  1463.000000
# mean     20.640465   241.038961
# std       8.423994   316.737329
# min       2.000000    13.000000
# 25%      14.000000    81.000000
# 50%      20.000000   140.000000
# 75%      27.000000   243.000000
# max      81.000000  2974.000000

# %%
import seaborn as sns
sns.histplot(df['review_len'], bins=30)
# Out:
# <Axes: xlabel='review_len', ylabel='Count'>

# %%
sns.heatmap(df[['discounted_price', 'rating', 'rating_count']].corr(), annot=True)
# Out:
# <Axes: >

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df['product_name'].astype(str).tolist())
wc = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Words in Product Names')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import matplotlib.pyplot as plt

vectorizer = CountVectorizer(stop_words='english', max_features=30)
bow = vectorizer.fit_transform(df['product_name'].astype(str))
word_freq = pd.DataFrame({
    'word': vectorizer.get_feature_names_out(),
    'count': bow.toarray().sum(axis=0)
}).sort_values(by='count', ascending=False)

plt.figure(figsize=(10,5))
plt.barh(word_freq['word'], word_freq['count'], color='skyblue')
plt.title('Top 30 Most Common Words in Product Names')
plt.xlabel('Count')
plt.gca().invert_yaxis()
plt.show()

# %%
# Split hierarchical categories into parts
cat_split = df['category'].str.split('|', expand=True)
df['main_category'] = cat_split[0]
df['sub_category1'] = cat_split[1]
df['sub_category2'] = cat_split[2]
df['sub_category3'] = cat_split[3]
df['sub_category4'] = cat_split[4]

df[['main_category', 'sub_category1', 'sub_category2', 'sub_category3']].head()
# Out:
#            main_category            sub_category1       sub_category2  \
# 0  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 1  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 2  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 3  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 4  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
#
#   sub_category3
# 0        Cables
# 1        Cables
# 2        Cables
# 3        Cables
# 4        Cables

# %%
print("Unique main categories:", df['main_category'].nunique())
print("Unique sub_category1:", df['sub_category1'].nunique())
print("Unique sub_category2:", df['sub_category2'].nunique())
print("Unique sub_category3:", df['sub_category3'].nunique())
# Out:
# Unique main categories: 9
# Unique sub_category1: 29
# Unique sub_category2: 71
# Unique sub_category3: 136

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
df['main_category'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Main Categories')
plt.xlabel('Main Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import seaborn as sns

sns.boxplot(x='main_category', y='name_len', data=df)
plt.xticks(rotation=45)
plt.title('Distribution of Product Name Lengths by Main Category')
plt.show()

# %%
sns.boxplot(x='main_category', y='review_len', data=df)
plt.xticks(rotation=45)
plt.title('Distribution of Review Lengths by Main Category')
plt.show()

# %%
category_rating = df.groupby('main_category')['rating'].mean().sort_values(ascending=False)
print(category_rating)
# Out:
# main_category
# OfficeProducts           4.309677
# Toys&Games               4.300000
# HomeImprovement          4.250000
# Computers&Accessories    4.155654
# Electronics              4.081749
# Home&Kitchen             4.040716
# Health&PersonalCare      4.000000
# MusicalInstruments       3.900000
# Car&Motorbike            3.800000
# Name: rating, dtype: float64
